# %%
from data_loader import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 30]
import numpy as np

# %%
d = DatasetFromHdf5('data/speedup_dataset.h5', maxsize=100000)

# %%
y = d.speedups
log_y = np.log(y)

norm = (log_y - np.mean(log_y))/np.std(log_y)#(np.max(y) - np.min(y))
plt.hist(log_y, bins=40)
# Out:
# (array([  45.,   75.,  159.,  103.,  351.,  412.,  329.,  443., 1145.,
#         1153.,  900., 1274., 1691., 1629., 2097., 2049., 1837., 2413.,
#         2617., 3949., 5076., 4477., 4795., 5600., 6005., 5484., 6268.,
#         7994., 6061., 4902., 2964., 2615., 3026., 5110., 4597., 2360.,
#          995.,  555.,  193.,   80.]),
#  array([-3.55374605, -3.39972287, -3.24569969, -3.09167651, -2.93765333,
#         -2.78363015, -2.62960697, -2.4755838 , -2.32156062, -2.16753744,
#         -2.01351426, -1.85949108, -1.7054679 , -1.55144472, -1.39742154,
#         -1.24339836, -1.08937518, -0.93535201, -0.78132883, -0.62730565,
#         -0.47328247, -0.31925929, -0.16523611, -0.01121293,  0.14281025,
#          0.29683343,  0.45085661,  0.60487978,  0.75890296,  0.91292614,
#          1.06694932,  1.2209725 ,  1.37499568,  1.52901886,  1.68304204,
#          1.83706522,  1.9910884 ,  2.14511157,  2.29913475,  2.45315793,
#          2.60718111]),
#  <a list of 40 Patch objects>)

# %%
# Out:
# 0.02861723706997252

# %%
plt.hist(norm, bins=40)
# Out:
# (array([  45.,   75.,  159.,  103.,  351.,  412.,  329.,  443., 1145.,
#         1153.,  900., 1274., 1691., 1629., 2097., 2049., 1837., 2413.,
#         2617., 3949., 5076., 4477., 4795., 5600., 6005., 5484., 6268.,
#         7994., 6061., 4902., 2964., 2615., 3026., 5110., 4597., 2360.,
#          995.,  555.,  193.,   80.]),
#  array([-3.44297652, -3.30225953, -3.16154253, -3.02082554, -2.88010854,
#         -2.73939155, -2.59867455, -2.45795756, -2.31724056, -2.17652357,
#         -2.03580657, -1.89508957, -1.75437258, -1.61365558, -1.47293859,
#         -1.33222159, -1.1915046 , -1.0507876 , -0.91007061, -0.76935361,
#         -0.62863662, -0.48791962, -0.34720263, -0.20648563, -0.06576864,
#          0.07494836,  0.21566536,  0.35638235,  0.49709935,  0.63781634,
#          0.77853334,  0.91925033,  1.05996733,  1.20068432,  1.34140132,
#          1.48211831,  1.62283531,  1.7635523 ,  1.9042693 ,  2.0449863 ,
#          2.18570329]),
#  <a list of 40 Patch objects>)
